# %% [markdown]
# Carga del archivo JSON
# • Cargue el archivo pokemonDB_dataset.json usando la
# librería json o pandas.
# • Explore su estructura inicial (keys(), items()) para
# entender su jerarquía.

# %%
import pandas as pd
import json

# ==========================================
# 1. CARGA DEL ARCHIVO JSON
# ==========================================

# Cargar el archivo usando la librería json
with open('pokemonDB_dataset.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# ==========================================
# 2. EXPLORAR ESTRUCTURA CON keys() e items()
# ==========================================

# Ver el tipo de estructura raíz (lista o diccionario)
print("Tipo de estructura:", type(data))

# Si es diccionario, explorar sus keys
if isinstance(data, dict):
    print("\nNúmero de Pokémon:", len(data))
    print("\nPrimeras 5 keys:", list(data.keys())[:5])
    
    # Obtener el primer Pokémon para explorar
    primer_key = list(data.keys())[0]
    primer_pokemon = data[primer_key]
    
# Si es lista, obtener el primer elemento
elif isinstance(data, list):
    print("\nNúmero de Pokémon:", len(data))
    primer_pokemon = data[0]

# Explorar la jerarquía del primer Pokémon usando items()
print(f"\nCampos del Pokémon (keys):")
print(list(primer_pokemon.keys()))

print(f"\nEstructura detallada (items):")
for key, value in primer_pokemon.items():
    # Mostrar cada campo con su tipo para entender la jerarquía
    print(f"  {key}: {type(value).__name__} = {value}")

# ==========================================
# 3. TRANSFORMAR A DATAFRAME
# ==========================================

# Convertir la estructura jerárquica a DataFrame
if isinstance(data, dict):
    df = pd.DataFrame.from_dict(data, orient='index')
else:
    df = pd.DataFrame(data)

print("\n" + "="*50)
print("DataFrame creado:")
print(f"Forma: {df.shape} (filas x columnas)")
print("\nPrimeras filas:")
print(df.head())
# Out:
# Tipo de estructura: <class 'dict'>
#
# Número de Pokémon: 1215
#
# Primeras 5 keys: ['Abomasnow', 'Mega Abomasnow', 'Abra', 'Absol', 'Mega Absol']
#
# Campos del Pokémon (keys):
# ['Type', 'Species', 'Height', 'Weight', 'Abilities', 'EV Yield', 'Catch Rate', 'Base Friendship', 'Base Exp', 'Growth Rate', 'Egg Groups', 'Gender', 'Egg Cycles', 'HP Base', 'HP Min', 'HP Max', 'Attack Base', 'Attack Min', 'Attack Max', 'Defense Base', 'Defense Min', 'Defense Max', 'Special Attack Base', 'Special Attack Min', 'Special Attack Max', 'Special Defense Base', 'Special Defense Min', 'Special Defense Max', 'Speed Base', 'Speed Min', 'Speed Max']
#
# Estructura detallada (items):
#   Type: str = Grass, Ice
#   Species: str = Frost Tree Pokémon
#   Height: str = 2.2 m (7′03″)
#   Weight: str = 135.5 kg (298.7 lbs)
#   Abilities: str = 1. Snow Warning, Soundproof (hidden ability)
#   EV Yield: str = 1 Attack, 1 Sp. Atk
#   Catch Rate: str = 60 (7.8% with PokéBall, full HP)
# ...

# %%
# ==========================================
# 2. REVISIÓN DE ESTRUCTURA Y TIPOS
# ==========================================

print("="*60)
print("REVISIÓN DE ESTRUCTURA Y TIPOS DE DATOS")
print("="*60)

# Usar df.info() para identificar tipos de datos
print("\n📊 df.info() - Información general del DataFrame:\n")
df.info()

# Usar df.describe(include='all') para estadísticas
print("\n" + "="*60)
print("\n📈 df.describe(include='all') - Estadísticas descriptivas:\n")
print(df.describe(include='all'))

# Determinar cuántas variables son numéricas y cuántas categóricas
print("\n" + "="*60)
print("CLASIFICACIÓN DE VARIABLES")
print("="*60)

# Contar variables numéricas
num_numericas = df.select_dtypes(include=['int64', 'float64']).shape[1]
columnas_numericas = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Contar variables categóricas (object)
num_categoricas = df.select_dtypes(include=['object']).shape[1]
columnas_categoricas = df.select_dtypes(include=['object']).columns.tolist()

# Mostrar resultados
print(f"\n✅ Total de variables NUMÉRICAS: {num_numericas}")
print("   Columnas:")
for col in columnas_numericas:
    print(f"   • {col}")

print(f"\n✅ Total de variables CATEGÓRICAS: {num_categoricas}")
print("   Columnas:")
for col in columnas_categoricas:
    print(f"   • {col}")

# Resumen final
print("\n" + "="*60)
print(f"RESUMEN: {num_numericas} numéricas + {num_categoricas} categóricas = {df.shape[1]} variables totales")
print("="*60)
# Out:
# ...
# REVISIÓN DE ESTRUCTURA Y TIPOS DE DATOS
# ...
#
# 📊 df.info() - Información general del DataFrame:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 1215 entries, Abomasnow to Zygarde Complete Forme
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Type                  1215 non-null   object
#  1   Species               1215 non-null   object
#  2   Height                1215 non-null   object
#  3   Weight                1215 non-null   object
#  4   Abilities             1215 non-null   object
#  5   EV Yield              1215 non-null   object
#  6   Catch Rate            1215 non-null   object
#  7   Base Friendship       1215 non-null   object
#  8   Base Exp              1215 non-null   object
#  9   Growth Rate           1215 non-null   object
#  10  Egg Groups            1215 non-null   object
#  11  Gender                1215 non-null   object
# ...

# %% [markdown]
# Esto es para ver todas las columnas y decidir cuáles necesitan convertirse a valores numericos

# %%
# Ver todas las columnas
print("Columnas del DataFrame:")
print(df.columns.tolist())
# Out:
# Columnas del DataFrame:
# ['Type', 'Species', 'Height', 'Weight', 'Abilities', 'EV Yield', 'Catch Rate', 'Base Friendship', 'Base Exp', 'Growth Rate', 'Egg Groups', 'Gender', 'Egg Cycles', 'HP Base', 'HP Min', 'HP Max', 'Attack Base', 'Attack Min', 'Attack Max', 'Defense Base', 'Defense Min', 'Defense Max', 'Special Attack Base', 'Special Attack Min', 'Special Attack Max', 'Special Defense Base', 'Special Defense Min', 'Special Defense Max', 'Speed Base', 'Speed Min', 'Speed Max']

# %%
# Ver columnas y sus tipos
print("Columnas y tipos de datos:")
print(df.dtypes)
# Out:
# Columnas y tipos de datos:
# Type                    object
# Species                 object
# Height                  object
# Weight                  object
# Abilities               object
# EV Yield                object
# Catch Rate              object
# Base Friendship         object
# Base Exp                object
# Growth Rate             object
# Egg Groups              object
# Gender                  object
# Egg Cycles              object
# HP Base                 object
# HP Min                  object
# HP Max                  object
# Attack Base             object
# Attack Min              object
# Attack Max              object
# Defense Base            object
# Defense Min             object
# Defense Max             object
# Special Attack Base     object
# Special Attack Min      object
# Special Attack Max      object
# Special Defense Base    object
# Special Defense Min     object
# Special Defense Max     object
# Speed Base              object
# ...

# %%
# ==========================================
# 3. LIMPIEZA Y CONVERSIÓN DE CAMPOS
# ==========================================

import re

print("="*60)
print("LIMPIEZA Y CONVERSIÓN DE CAMPOS")
print("="*60)

# Crear copia del DataFrame
df_clean = df.copy()

# ==========================================
# PASO 1: Convertir columnas numéricas
# ==========================================

print("\n🔧 Convirtiendo columnas a tipo float...\n")

# Función para limpiar valores numéricos
def limpiar_numerico(valor):
    """Elimina unidades (m, kg, lbs, %) y convierte a float"""
    if pd.isna(valor):
        return None
    # Extraer solo números y puntos decimales
    numeros = re.findall(r'\d+\.?\d*', str(valor))
    if numeros:
        return float(numeros[0])
    return None

# Identificar columnas que deben ser numéricas
palabras_clave = ['hp', 'attack', 'defense', 'speed', 'sp', 'height', 'weight', 'base', 'exp']
columnas_numericas = [col for col in df_clean.columns 
                      if any(palabra in col.lower() for palabra in palabras_clave)]

# Convertir cada columna
for col in columnas_numericas:
    df_clean[col] = df_clean[col].apply(limpiar_numerico)
    print(f"   ✓ {col} convertida a float")

# Renombrar Height y Weight
if 'Height' in df_clean.columns:
    df_clean.rename(columns={'Height': 'Height_m'}, inplace=True)
    print(f"   ✓ 'Height' renombrada a 'Height_m'")

if 'Weight' in df_clean.columns:
    df_clean.rename(columns={'Weight': 'Weight_kg'}, inplace=True)
    print(f"   ✓ 'Weight' renombrada a 'Weight_kg'")

# ==========================================
# PASO 2: Separar columnas compuestas
# ==========================================

print("\n🔧 Separando columnas compuestas...\n")

# Separar Type → Type1, Type2
if 'Type' in df_clean.columns:
    df_clean['Type1'] = df_clean['Type'].apply(
        lambda x: str(x).split(',')[0].strip() if pd.notna(x) else None
    )
    df_clean['Type2'] = df_clean['Type'].apply(
        lambda x: str(x).split(',')[1].strip() if pd.notna(x) and ',' in str(x) else None
    )
    df_clean.drop('Type', axis=1, inplace=True)
    print("   ✓ 'Type' separada en Type1 y Type2")

# Separar Gender → Male (%), Female (%)
if 'Gender' in df_clean.columns:
    df_clean['Male (%)'] = df_clean['Gender'].apply(
        lambda x: limpiar_numerico(str(x).split(',')[0]) if pd.notna(x) and ',' in str(x) else None
    )
    df_clean['Female (%)'] = df_clean['Gender'].apply(
        lambda x: limpiar_numerico(str(x).split(',')[1]) if pd.notna(x) and ',' in str(x) else None
    )
    df_clean.drop('Gender', axis=1, inplace=True)
    print("   ✓ 'Gender' separada en Male (%) y Female (%)")

# ==========================================
# PASO 3: Verificación final
# ==========================================

print("\n" + "="*60)
print("VERIFICACIÓN FINAL")
print("="*60)

# Contar valores nulos
valores_nulos = df_clean.isnull().sum().sum()
print(f"\n🔍 Total de valores nulos: {valores_nulos}")

# Contar variables numéricas y categóricas
num_numericas = df_clean.select_dtypes(include=['int64', 'float64']).shape[1]
num_categoricas = df_clean.select_dtypes(include=['object']).shape[1]

print(f"\n📊 Variables después de la limpieza:")
print(f"   • Numéricas: {num_numericas}")
print(f"   • Categóricas: {num_categoricas}")
print(f"   • Total: {df_clean.shape[1]}")

print(f"\n✅ DataFrame limpio creado: df_clean")
print(f"   Forma: {df_clean.shape} (filas x columnas)")

# Mostrar primeras filas
print("\n📋 Primeras 3 filas del DataFrame limpio:")
print(df_clean.head(3))
# Out:
# ...
# LIMPIEZA Y CONVERSIÓN DE CAMPOS
# ...
#
# 🔧 Convirtiendo columnas a tipo float...
#
#    ✓ Species convertida a float
#    ✓ Height convertida a float
#    ✓ Weight convertida a float
#    ✓ Base Friendship convertida a float
#    ✓ Base Exp convertida a float
#    ✓ HP Base convertida a float
#    ✓ HP Min convertida a float
#    ✓ HP Max convertida a float
#    ✓ Attack Base convertida a float
#    ✓ Attack Min convertida a float
#    ✓ Attack Max convertida a float
#    ✓ Defense Base convertida a float
#    ✓ Defense Min convertida a float
#    ✓ Defense Max convertida a float
#    ✓ Special Attack Base convertida a float
#    ✓ Special Attack Min convertida a float
#    ✓ Special Attack Max convertida a float
#    ✓ Special Defense Base convertida a float
#    ✓ Special Defense Min convertida a float
#    ✓ Special Defense Max convertida a float
#    ✓ Speed Base convertida a float
#    ✓ Speed Min convertida a float
#    ✓ Speed Max convertida a float
# ...

# %%
# ==========================================
# 4. NORMALIZACIÓN Y VERIFICACIÓN FINAL
# ==========================================

print("="*60)
print("NORMALIZACIÓN Y VERIFICACIÓN FINAL")
print("="*60)

# ==========================================
# PASO 1: Verificar valores nulos y duplicados
# ==========================================

print("\n🔍 Verificando valores nulos...\n")

# Contar valores nulos por columna
valores_nulos = df_clean.isnull().sum()

# Mostrar solo columnas con valores nulos
if valores_nulos.sum() > 0:
    print("Columnas con valores nulos:")
    for col, nulos in valores_nulos[valores_nulos > 0].items():
        print(f"   • {col}: {nulos} nulos")
    print(f"\n   Total de valores nulos: {valores_nulos.sum()}")
else:
    print("   ✅ No hay valores nulos")

# Verificar duplicados
print("\n🔍 Verificando filas duplicadas...\n")
duplicados = df_clean.duplicated().sum()
print(f"   Filas duplicadas: {duplicados}")

if duplicados > 0:
    print(f"   ⚠️ Se encontraron {duplicados} filas duplicadas")
else:
    print("   ✅ No hay filas duplicadas")

# ==========================================
# PASO 2: Crear DataFrame final con campos específicos
# ==========================================

print("\n" + "="*60)
print("CREANDO DATAFRAME FINAL")
print("="*60)

# Campos requeridos según el enunciado
campos_requeridos = [
    "Type1", "Type2", "HP Base", "Attack Base", "Defense Base",
    "Speed Base", "Height_m", "Weight_kg", "Base Exp"
]

# Verificar qué campos existen
campos_disponibles = [col for col in campos_requeridos if col in df_clean.columns]
campos_faltantes = [col for col in campos_requeridos if col not in df_clean.columns]

print(f"\n📋 Campos disponibles: {len(campos_disponibles)}/{len(campos_requeridos)}")

if campos_faltantes:
    print(f"\n⚠️ Campos faltantes: {campos_faltantes}")

# Crear df_clean con solo los campos requeridos
df_clean = df_clean[campos_disponibles]

print(f"\n✅ DataFrame final creado con {len(campos_disponibles)} campos")
print(f"   Forma: {df_clean.shape} (filas x columnas)")

# ==========================================
# PASO 3: Verificación final del DataFrame
# ==========================================

print("\n" + "="*60)
print("INFORMACIÓN DEL DATAFRAME FINAL")
print("="*60)

# Mostrar información general
print("\n📊 df_clean.info():\n")
df_clean.info()

# Mostrar estadísticas descriptivas
print("\n📈 df_clean.describe():\n")
print(df_clean.describe())

# Mostrar primeras filas
print("\n📋 Primeras 5 filas del DataFrame final:\n")
print(df_clean.head())

# Resumen final
print("\n" + "="*60)
print("RESUMEN FINAL")
print("="*60)

num_numericas_final = df_clean.select_dtypes(include=['int64', 'float64']).shape[1]
num_categoricas_final = df_clean.select_dtypes(include=['object']).shape[1]

print(f"\n✅ DataFrame df_clean listo para análisis")
print(f"   • Total de filas (Pokémon): {df_clean.shape[0]}")
print(f"   • Total de columnas: {df_clean.shape[1]}")
print(f"   • Variables numéricas: {num_numericas_final}")
print(f"   • Variables categóricas: {num_categoricas_final}")
print(f"   • Valores nulos: {df_clean.isnull().sum().sum()}")
print(f"\n📁 Columnas finales: {list(df_clean.columns)}")

print("\n" + "="*60)
print("✅ ETAPA 1 COMPLETADA")
print("="*60)
# Out:
# ...
# NORMALIZACIÓN Y VERIFICACIÓN FINAL
# ...
#
# 🔍 Verificando valores nulos...
#
# Columnas con valores nulos:
#    • Species: 1215 nulos
#    • Weight_kg: 1 nulos
#    • Base Friendship: 23 nulos
#    • Base Exp: 23 nulos
#    • Type2: 546 nulos
#    • Male (%): 197 nulos
#    • Female (%): 197 nulos
#
#    Total de valores nulos: 2202
#
# 🔍 Verificando filas duplicadas...
#
#    Filas duplicadas: 7
#    ⚠️ Se encontraron 7 filas duplicadas
#
# ...
# CREANDO DATAFRAME FINAL
# ...
#
# 📋 Campos disponibles: 9/9
#
# ✅ DataFrame final creado con 9 campos
#    Forma: (1215, 9) (filas x columnas)
#
# ...
# INFORMACIÓN DEL DATAFRAME FINAL
# ...
#
# 📊 df_clean.info():
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 1215 entries, Abomasnow to Zygarde Complete Forme
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Type1         1215 non-null   object
#  1   Type2         669 non-null    object
#  2   HP Base       1215 non-null   float64
# ...
